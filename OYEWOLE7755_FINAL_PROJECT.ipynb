# %% [markdown]
# <a href="https://colab.research.google.com/github/oyemakinde/deeplearning_projects/blob/main/OYEWOLE7755_FINAL_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Good day! I'd like to share my final project,
#which I've been working on for the past couple of days.
#The project involves training a model to achieve optimal accuracy.
#Unfortunately, I encountered a challenge with the lengthy training time,
#preventing me from completing the training within the given timeframe.
#Below is the complete code for the final project:

# %%
import os #allows us ro use os commands
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.image import imread # this will allow us to read images directly

# %%
from google.colab import drive
#MOUNT DATA
drive.mount('/content/drive')

# %%
data_dir= '/content/drive/MyDrive/final_project_data/final_project_data'

# %%
os.listdir(data_dir)
# Out:
# ['training', 'test', 'validation']

# %%
test_path= data_dir+'/test/'
training_path = data_dir+'/training/'
validation_path = data_dir+ '/validation/'

# %%
os.listdir(test_path)
os.listdir(training_path)
os.listdir(validation_path)
# Out:
# ['steak', 'spring_rolls', 'pizza', 'donuts', 'onion_rings']

# %%
os.listdir(training_path)
# Out:
# ['donuts', 'onion_rings', 'steak', 'pizza', 'spring_rolls']

# %%
test_steak= os.listdir(test_path+'steak')
test_spring_rolls = os.listdir(test_path+'spring_rolls')
test_pizza= os.listdir(test_path+'pizza')
test_donuts= os.listdir(test_path+'donuts')
test_onion_rings= os.listdir(test_path+'onion_rings')

training_steak= os.listdir(training_path+'steak')
training_spring_rolls = os.listdir(training_path+'spring_rolls')
training_pizza= os.listdir(training_path+'pizza')
training_donuts= os.listdir(training_path+'donuts')
training_onion_rings= os.listdir(training_path+'onion_rings')

validation_steak= os.listdir(validation_path+'steak')
validation_spring_rolls = os.listdir(validation_path+'spring_rolls')
validation_pizza= os.listdir(validation_path+'pizza')
validation_donuts= os.listdir(validation_path+'donuts')
validation_onion_rings= os.listdir(validation_path+'onion_rings')

# %%
image_dim1 =[]
image_dim2 =[]

for image_filename in training_donuts:
  img = imread(training_path+'donuts/'+image_filename)
  d1,d2, colors = img.shape
  image_dim1.append(d1)
  image_dim2.append(d2)

# %%
image_dim2
# Out:
# [384,
#  512,
#  512,
#  512,
#  512,
#  512,
#  382,
#  512,
#  512,
#  384,
#  382,
#  382,
#  382,
#  512,
#  382,
#  384,
#  512,
#  512,
#  384,
#  512,
#  512,
#  512,
#  382,
#  512,
#  382,
#  512,
#  512,
#  512,
#  512,
#  512,
#  320,
#  504,
#  512,
#  384,
#  512,
#  512,
#  512,
#  384,
#  512,
#  384,
#  384,
#  341,
#  512,
#  384,
#  512,
#  384,
#  382,
#  512,
#  438,
#  512,
#  512,
#  512,
#  382,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  384,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  384,
#  384,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  382,
#  512,
#  512,
#  512,
#  512,
#  512,
#  384,
#  512,
#  384,
#  384,
#  382,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  384,
#  512,
#  512,
#  384,
#  512,
#  512,
#  512,
#  384,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
# ...

# %%
image_dim1
# Out:
# [512,
#  384,
#  384,
#  382,
#  389,
#  512,
#  512,
#  384,
#  384,
#  512,
#  512,
#  512,
#  512,
#  384,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  384,
#  512,
#  382,
#  384,
#  512,
#  512,
#  342,
#  512,
#  384,
#  382,
#  384,
#  512,
#  512,
#  512,
#  512,
#  512,
#  384,
#  512,
#  384,
#  512,
#  512,
#  512,
#  512,
#  382,
#  512,
#  512,
#  512,
#  512,
#  341,
#  384,
#  512,
#  512,
#  512,
#  384,
#  512,
#  512,
#  512,
#  512,
#  384,
#  512,
#  512,
#  512,
#  512,
#  289,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  384,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  334,
#  512,
#  512,
#  512,
#  512,
#  512,
#  384,
#  509,
#  512,
#  512,
#  512,
#  342,
#  512,
#  512,
#  512,
#  512,
#  512,
#  384,
#  378,
#  288,
#  512,
#  384,
#  512,
#  512,
#  512,
#  512,
#  512,
#  512,
#  289,
#  512,
#  384,
#  512,
#  384,
#  512,
#  384,
#  512,
#  512,
#  512,
#  512,
# ...

# %%
# to reshape images to be 480 x480 x 3
print (np.mean(image_dim1))
print (np.mean(image_dim2))
# Out:
# 472.68142857142857
# 491.8985714285714

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
image_gen = ImageDataGenerator(rotation_range= 10,
                               width_shift_range=0.10,
                               height_shift_range=0.10,
                               shear_range=0.1,
                               zoom_range=0.1,
                               horizontal_flip= True,
                               fill_mode='nearest')

# %%
image_gen.flow_from_directory(training_path)
# Out:
# Found 3500 images belonging to 5 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D

# %%
image_shape = (480, 480, 3)
model= Sequential()

# %%
model.add(Conv2D(filters=32, kernel_size=(3,3),input_shape=image_shape, activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=64, kernel_size=(3,3),input_shape=image_shape, activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=64, kernel_size=(3,3),input_shape=image_shape, activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=64, kernel_size=(3,3),input_shape=image_shape, activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())

model.add(Dense(150))
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Dense(5))
model.add(Activation('softmax')) # Using 'softmax' for multi-class classification

model.compile(loss='categorical_crossentropy', # For multi-class classification
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 478, 478, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 239, 239, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 237, 237, 64)      18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 118, 118, 64)      0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 116, 116, 64)      36928
#
#  max_pooling2d_2 (MaxPoolin  (None, 58, 58, 64)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 56, 56, 64)        36928
#
#  max_pooling2d_3 (MaxPoolin  (None, 28, 28, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 50176)             0
#
#  dense (Dense)               (None, 150)               7526550
#
#  activation (Activation)     (None, 150)               0
#
#  dropout (Dropout)           (None, 150)               0
#
#  dense_1 (Dense)             (None, 5)                 755
#
# ...

# %%
batch_size = 50

# %%
train_image_gen = image_gen.flow_from_directory(training_path,
                                                target_size=image_shape[:2],
                                                color_mode='rgb',
                                                batch_size=batch_size,
                                                class_mode='categorical')
# Out:
# Found 3500 images belonging to 5 classes.

# %%
val_image_gen = image_gen.flow_from_directory(validation_path,
                                                target_size=image_shape[:2],
                                                color_mode='rgb',
                                                batch_size=batch_size,
                                                class_mode='categorical', shuffle=False)
# Out:
# Found 1000 images belonging to 5 classes.

# %%
test_image_gen = image_gen.flow_from_directory(test_path,
                                                target_size=image_shape[:2],
                                                color_mode='rgb',
                                                batch_size=batch_size,
                                                class_mode='categorical', shuffle=False)
# Out:
# Found 500 images belonging to 5 classes.

# %%
train_image_gen.class_indices # shows how many classes
# Out:
# {'donuts': 0, 'onion_rings': 1, 'pizza': 2, 'spring_rolls': 3, 'steak': 4}

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor ='val_loss', patience = 10)

# %%
results = model.fit(train_image_gen, epochs=5, validation_data=val_image_gen, callbacks=[early_stop])
# Out:
# Epoch 1/5
# 70/70 [==============================] - 2102s 30s/step - loss: 14.9994 - accuracy: 0.2123 - val_loss: 1.6067 - val_accuracy: 0.2150
# Epoch 2/5
# 70/70 [==============================] - 1854s 26s/step - loss: 1.5978 - accuracy: 0.2494 - val_loss: 1.5966 - val_accuracy: 0.2650
# Epoch 3/5
# 70/70 [==============================] - 1833s 26s/step - loss: 1.6036 - accuracy: 0.2366 - val_loss: 1.6041 - val_accuracy: 0.2590
# Epoch 4/5
# 55/70 [======================>.......] - ETA: 5:53 - loss: 1.6090 - accuracy: 0.2218

# %%
#Evaluate the model
# the training model
traininghistory = Pd.DataFrame (model.history.history)

# %%
traininghistory[['loss', 'val_loss']].plot()

# %%
traininghistory[['accuracy', 'val_accuracy']].plot()

# %%
model.metrics_names

# %%
model.evalute_generator(val_image_gen)

# %%
val_image_gen.class_indices

# %%
val_image_gen.classes

# %%
#print ptobability
print(np.round(pred_probabilities,2))

# %%
from sklearn.matrics import classification_report, confusion_matrix

# %%
prediction = pred_probabilities >

# %%
print ( classification_report(val_image_gen.classes.predictions))

# %%
confusion_matrix(val_image_gen.classes.predictions)

# %%
#test to see how the model predicts a cell from the data set
test_donut_cell = test_path+'donuts/' +os.listdir(test_path+'donuts')[0]
test_donut_cell

# %%
from tensorflow.karas.preprocessing import image

# %%
test_donut_image = image.load_img(test_donut_cell, target_size = image_shape )
test_donut_image

# %%
type (test_donut_image)

# %%
test_donut_image.shape

# %%
test_donut_image= np.expand_dims(test_donut_image, axis =0)

# %%
test_donut_image.shape

# %%
model.predict(test_donut_image)
